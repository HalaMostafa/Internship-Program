# %% [markdown]
# # Intro to Data Analysis with pandas
#
# ## Overview
#
# ### Objectives
#
# + Know why pandas is suitable for data analysis in Python.
# + load csv data into pandas dataframe.
# + Identify a DataFrame as a two-dimensional data structure with an **index**, **columns**, and **values**.
# + Identify a Series as a single dimensional data structure with an **index** and **values**.
# + Know the difference between the **index** and **values**.
# + ways to show sample of dataset or specefic rows.
# + ways to describe/get ingo about the whole data set.
# + check/change data types.
# + check missing values.
#
# ### Resources
#
# + [Official Documentation](http://pandas.pydata.org/pandas-docs/stable/)
# + [Package Overview](http://pandas.pydata.org/pandas-docs/stable/overview.html)
# + [Intro to Data Structures](http://pandas.pydata.org/pandas-docs/stable/dsintro.html)
#
# ## Welcome to ....
# ![][1]
#
#
# ### What is pandas?
# pandas is one of the most popular open source data exploration libraries currently available. It gives its users the power to explore, manipulate, query, aggregate, and visualize **tabular** data. Tabular meaning data that is two-dimensional with rows and columns; i.e. a table.
#
# ### Why pandas and not xyz?
# In this current age of data explosion, there are now many dozens of other tools that have many of the same capabilities as the pandas library. However, there are many aspects of pandas that make it an attractive choice for data analysis and it continues to have one of the fastest growing user bases.
#
# * It's a Python library and integrates well with the other popular data science libraries such as numpy, scikit-learn, statsmodels, matplotlib and seaborn.
# * It is nearly self-contained in that lots of functionality is built into one package. This contrasts with R, where many packages are needed to obtain the same functionality.
# * The community is excellent. Looking at Stack Overflow, for example, there are [many ten's of thousands of][2] pandas questions. If you need help, you are nearly guaranteed to find it very quickly.
#
# ### Why is it named after an East Asian bear?
#
# The pandas library was begun by Wes McKinney beginning in 2008 at a hedge fund named AQR. Finance speak is to call tabular data 'panel data' which smashed together becomes pandas. If you are really interested in the history, you can hear it from the creator [himself][3].
#
# ### Python already has data structures to handle data, why do we need another one?
#
# Even though Python is a high-level language, its primary built-in data structures lists and dictionaries, do not easily lend themselves to tabular data analysis in ways that humans can operate on them.
#
# ### pandas is built directly on numpy
#
# [numpy][4] ('numerical Python') is the most popular third-party Python library for scientific computing and forms the foundation for dozens of others, including pandas. numpy's primary data structure is an n-dimensional array which is much more powerful than a Python list and with much better performance.
#
# All of the data in pandas is stored in numpy arrays. That said, it isn't necessary to know much about numpy when learning pandas. You can think of pandas as a higher-level, easier to use interface for doing data analysis than numpy. It is a good idea to eventually learn numpy, but for most tasks, pandas will be the right tool.
#
# ### numpy tutorial in appendix
#
# Although it is not necessary to understand numpy to perform data analysis with pandas, it is a major piece of the data science ecosystem in Python and it can be used alongside pandas. A thorough numpy tutorial is available in Appendix A.
#
# ## pandas operates on tabular (table) data
#
# There are numerous formats for data such as XML, JSON, raw bytes, and many others. But, for our purposes, we will only be examining what most people think of when they think of data - a table. pandas is built just for analyzing this tabular, rectangular, very deceptively normal concept of data. pandas has the capability to read in many different formats of data, but they all will be converted to tabular data.
#
# ### The DataFrame and Series
#
# The DataFrame and Series are the two primary pandas objects that we will be using throughout this course.
#
# * **DataFrame** - A two-dimensional data structure that looks like any other rectangular table of data you have seen with rows and columns.
# * **Series** - A single dimension of data. It is analogous to a single column of data or a one dimensional array.
#
# ## Import pandas and read in data with the `read_csv` function
#
# By convention, pandas is imported and aliased as `pd`. We will read in the `bikes` dataset with the `read_csv` function. Its first parameter is the location of the file relative to the current directory as a string. All of the data for this course is stored in the `data` directory one level above where this notebook is located. The two dots in the path passed to `read_csv` are interpreted as the directory immediately above the current one.
#
# [1]: images/pandas_logo.png
# [2]: http://stackoverflow.com/questions/tagged/pandas
# [3]: https://www.youtube.com/watch?v=kHdkFyGCxiY
# [4]: http://www.numpy.org/

# %%
import pandas as pd

# %%
bikes = pd.read_csv('data/bikes.csv')
type(bikes)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Display DataFrame in Jupyter Notebook
# We assigned the output from the `read_csv` function to the `bikes` variable which now refers to our DataFrame object. Let's get a visual display of our DataFrame by writing the variable name as the last line in a code cell.

# %%
bikes
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907  Subscriber    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# ...         ...         ...     ...                  ...                  ...
# 50084  17534938  Subscriber    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration             from_station_name  latitude_start  \
# 0               993     Lake Shore Dr & Monroe St       41.881050
# 1               623  Clinton St & Washington Blvd       41.883380
# 2              1040  Sheffield Ave & Kingsbury St       41.909592
# 3               667       Carpenter St & Huron St       41.894556
# 4               130        Damen Ave & Pierce Ave       41.909396
# ...             ...                           ...             ...
# 50084          1625         State St & Pearson St       41.897448
# 50085           585      Halsted St & 35th St (*)       41.830661
# 50086           824      Kingsbury St & Kinzie St       41.889177
# 50087           178          Clinton St & Lake St       41.885637
# 50088           214    Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 0           -87.616970              11.0          Michigan Ave & Oak St
# 1           -87.641170              31.0           Wells St & Walton St
# 2           -87.653497              15.0        Dearborn St & Monroe St
# 3           -87.653449              19.0         Clark St & Randolph St
# 4           -87.677692              19.0         Damen Ave & Pierce Ave
# ...                ...               ...                            ...
# 50084       -87.628722              27.0              Clark St & Elm St
# 50085       -87.647172              16.0            Union Ave & Root St
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 0         41.900960     -87.623777            15.0         73.9        10.0
# 1         41.899930     -87.634430            19.0         69.1        10.0
# 2         41.881320     -87.629521            23.0         73.0        10.0
# 3         41.884576     -87.631890            31.0         72.0        10.0
# 4         41.909396     -87.677692            19.0         73.0        10.0
# ...             ...            ...             ...          ...         ...
# 50084     41.902973     -87.631280            27.0          5.0        10.0
# 50085     41.819102     -87.643278            11.0          5.0        10.0
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 0            12.7        -9999.0  mostlycloudy
# 1             6.9        -9999.0  partlycloudy
# 2            16.1        -9999.0  mostlycloudy
# 3            16.1        -9999.0  mostlycloudy
# 4            17.3        -9999.0  partlycloudy
# ...           ...            ...           ...
# 50084        16.1        -9999.0  partlycloudy
# 50085        16.1        -9999.0  partlycloudy
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy
#
# [50089 rows x 19 columns]

# %% [markdown]
# ### Default output
# pandas defaults to outputting 60 rows and 20 columns. These display options (and many others) can be changed. This will be covered later.
#
# ## Our first methods - `head`, `tail`, and `sample`
# A very useful and simple method is `head`, which by default will return the first 5 rows of the DataFrame. This avoids long default output and is something I highly recommend when doing data analysis within a notebook. The `tail` method returns the last 5 rows by default.

# %%
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0     Wells St & Walton St     41.899930
# 2       -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 3       -87.653449              19.0   Clark St & Randolph St     41.884576
# 4       -87.677692              19.0   Damen Ave & Pierce Ave     41.909396
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
# 3     -87.631890            31.0         72.0        10.0        16.1
# 4     -87.677692            19.0         73.0        10.0        17.3
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy
# 3        -9999.0  mostlycloudy
# 4        -9999.0  partlycloudy

# %%
bikes.tail(3)
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 50086  17534972  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration           from_station_name  latitude_start  \
# 50086           824    Kingsbury St & Kinzie St       41.889177
# 50087           178        Clinton St & Lake St       41.885637
# 50088           214  Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy

# %%
#sample()
bikes.sample(10)
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 29276  11166434  Subscriber  Female  2016-08-06 15:31:09  2016-08-06 15:50:13
# 22333   8782215  Subscriber    Male  2016-02-20 18:39:00  2016-02-20 18:58:00
# 10401   4468701  Subscriber  Female  2015-01-22 18:33:00  2015-01-22 18:39:00
# 16049   6757498  Subscriber    Male  2015-08-07 17:00:00  2015-08-07 17:18:00
# 41927  15036744  Subscriber  Female  2017-07-09 10:37:35  2017-07-09 10:49:11
# 45720  16279169  Subscriber    Male  2017-09-07 08:09:17  2017-09-07 08:27:39
# 34898  12884531  Subscriber    Male  2016-12-06 06:48:17  2016-12-06 07:08:40
# 11392   4875763  Subscriber    Male  2015-04-15 18:06:00  2015-04-15 18:18:00
# 39530  14244733  Subscriber    Male  2017-05-30 20:32:27  2017-05-30 20:57:44
# 14461   6111878  Subscriber  Female  2015-07-08 16:35:00  2015-07-08 16:43:00
#
#        tripduration                from_station_name  latitude_start  \
# 29276          1144  Lakefront Trail & Bryn Mawr Ave       41.984037
# 22333          1131             Larrabee St & Oak St       41.900219
# 10401           319      Lincoln Ave & Diversey Pkwy       41.932225
# 16049          1090     Ashland Ave & Wrightwood Ave       41.928830
# 41927           696       Wilton Ave & Diversey Pkwy       41.932418
# 45720          1102     Michigan Ave & Washington St       41.883893
# 34898          1223   Lake Shore Dr & Wellington Ave       41.936669
# 11392           737         Loomis St & Jackson Blvd       41.877945
# 39530          1517    Lake Shore Dr & Diversey Pkwy       41.932684
# 14461           453          Dearborn St & Monroe St       41.881320
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 29276       -87.652310              19.0    Lake Shore Dr & Belmont Ave
# 22333       -87.642985              15.0           Clinton St & 18th St
# 10401       -87.658617              15.0    Halsted St & Wrightwood Ave
# 16049       -87.668507              15.0        Ashland Ave & Grand Ave
# 41927       -87.652705              27.0  Greenview Ave & Fullerton Ave
# 45720       -87.624649              43.0           Ogden Ave & Race Ave
# 34898       -87.636794              15.0        Streeter Dr & Grand Ave
# 11392       -87.662007              11.0       Loomis St & Lexington St
# 39530       -87.636250              15.0        Dearborn St & Monroe St
# 14461       -87.629521              27.0         Michigan Ave & Lake St
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 29276     41.940775     -87.639192            19.0         82.9        10.0
# 22333     41.857950     -87.640826            15.0         45.0        10.0
# 10401     41.929143     -87.649077            15.0         30.9        10.0
# 16049     41.891072     -87.666611            15.0         80.1        10.0
# 41927     41.925330     -87.665800            15.0         80.1        10.0
# 45720     41.891795     -87.658751            15.0         59.0        10.0
# 34898     41.892278     -87.612043            47.0         28.0         0.5
# 11392     41.872187     -87.661501            15.0         57.0        10.0
# 39530     41.881320     -87.629521            27.0         64.9        10.0
# 14461     41.886024     -87.624117            31.0         64.0        10.0
#
#        wind_speed  precipitation        events
# 29276         4.6        -9999.0  partlycloudy
# 22333         6.9        -9999.0  partlycloudy
# 10401         5.8        -9999.0        cloudy
# 16049        10.4        -9999.0  mostlycloudy
# 41927         9.2        -9999.0  partlycloudy
# 45720         8.1        -9999.0  mostlycloudy
# 34898         4.6        -9999.0           fog
# 11392        12.7        -9999.0  mostlycloudy
# 39530         4.6        -9999.0  partlycloudy
# 14461         8.1            0.0          rain

# %% [markdown]
# ### First and Last `n` rows
# Both the `head` and `tail` methods take a single integer parameter `n`, which controls the number of rows to return.

# %%
bikes.head(2)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St        41.88105
# 1           623  Clinton St & Washington Blvd        41.88338
#
#    longitude_start  dpcapacity_start        to_station_name  latitude_end  \
# 0        -87.61697              11.0  Michigan Ave & Oak St      41.90096
# 1        -87.64117              31.0   Wells St & Walton St      41.89993
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy

# %% [markdown]
# ## Components of a DataFrame - columns, index, and data
# The DataFrame is composed of three separate components that you must know. The **columns**, the **index**, and the **data**. These terms will be used throughout the course and understanding them is vital to your ability to use pandas. Take a look at the following graphic of our `bikes` DataFrame stylized to put emphasis on each component.
#
# ![][1]
#
# [1]: images/df_components.png

# %% [markdown]
# * The **index** provides a label for each row
# * The **columns** provide a label for each column
# * The **index** is also referred to as the **row names/labels**
# * The **columns** are also referred to as the **column names/labels** or the **column index**
# * An individual element of the index is referred to as an **index label/name** or **row label/name**
# * An individual element of the columns is a **column name/label**
# * The index and the columns are always in **bold font**
# * Collectively the index and the columns are known as the **axes** (or individually as an **axis**)
# * pandas uses integers to refer to each axis; 0 for the index and 1 for the columns. This is borrowed directly from numpy
# * The actual **data** is always in normal font
# * The **data** is also referred to as the **values**

# %% [markdown]
# ## What type of object is `bikes`
# As we said previously, `bikes` is a DataFrame. Let's verify this:

# %%
type(bikes)
# Out:
# pandas.core.frame.DataFrame

# %%
bikes
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber    Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber    Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927  Subscriber    Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907  Subscriber    Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber    Male  2013-07-01 11:16:00  2013-07-01 11:18:00
# ...         ...         ...     ...                  ...                  ...
# 50084  17534938  Subscriber    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration             from_station_name  latitude_start  \
# 0               993     Lake Shore Dr & Monroe St       41.881050
# 1               623  Clinton St & Washington Blvd       41.883380
# 2              1040  Sheffield Ave & Kingsbury St       41.909592
# 3               667       Carpenter St & Huron St       41.894556
# 4               130        Damen Ave & Pierce Ave       41.909396
# ...             ...                           ...             ...
# 50084          1625         State St & Pearson St       41.897448
# 50085           585      Halsted St & 35th St (*)       41.830661
# 50086           824      Kingsbury St & Kinzie St       41.889177
# 50087           178          Clinton St & Lake St       41.885637
# 50088           214    Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 0           -87.616970              11.0          Michigan Ave & Oak St
# 1           -87.641170              31.0           Wells St & Walton St
# 2           -87.653497              15.0        Dearborn St & Monroe St
# 3           -87.653449              19.0         Clark St & Randolph St
# 4           -87.677692              19.0         Damen Ave & Pierce Ave
# ...                ...               ...                            ...
# 50084       -87.628722              27.0              Clark St & Elm St
# 50085       -87.647172              16.0            Union Ave & Root St
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 0         41.900960     -87.623777            15.0         73.9        10.0
# 1         41.899930     -87.634430            19.0         69.1        10.0
# 2         41.881320     -87.629521            23.0         73.0        10.0
# 3         41.884576     -87.631890            31.0         72.0        10.0
# 4         41.909396     -87.677692            19.0         73.0        10.0
# ...             ...            ...             ...          ...         ...
# 50084     41.902973     -87.631280            27.0          5.0        10.0
# 50085     41.819102     -87.643278            11.0          5.0        10.0
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 0            12.7        -9999.0  mostlycloudy
# 1             6.9        -9999.0  partlycloudy
# 2            16.1        -9999.0  mostlycloudy
# 3            16.1        -9999.0  mostlycloudy
# 4            17.3        -9999.0  partlycloudy
# ...           ...            ...           ...
# 50084        16.1        -9999.0  partlycloudy
# 50085        16.1        -9999.0  partlycloudy
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy
#
# [50089 rows x 19 columns]

# %%
bikes.head()
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2    10927  Subscriber   Male  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3    12907  Subscriber   Male  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4    13168  Subscriber   Male  2013-07-01 11:16:00  2013-07-01 11:18:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St       41.881050
# 1           623  Clinton St & Washington Blvd       41.883380
# 2          1040  Sheffield Ave & Kingsbury St       41.909592
# 3           667       Carpenter St & Huron St       41.894556
# 4           130        Damen Ave & Pierce Ave       41.909396
#
#    longitude_start  dpcapacity_start          to_station_name  latitude_end  \
# 0       -87.616970              11.0    Michigan Ave & Oak St     41.900960
# 1       -87.641170              31.0     Wells St & Walton St     41.899930
# 2       -87.653497              15.0  Dearborn St & Monroe St     41.881320
# 3       -87.653449              19.0   Clark St & Randolph St     41.884576
# 4       -87.677692              19.0   Damen Ave & Pierce Ave     41.909396
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
# 2     -87.629521            23.0         73.0        10.0        16.1
# 3     -87.631890            31.0         72.0        10.0        16.1
# 4     -87.677692            19.0         73.0        10.0        17.3
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy
# 2        -9999.0  mostlycloudy
# 3        -9999.0  mostlycloudy
# 4        -9999.0  partlycloudy

# %%
bikes.head(2)
# Out:
#    trip_id    usertype gender            starttime             stoptime  \
# 0     7147  Subscriber   Male  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1     7524  Subscriber   Male  2013-06-28 22:53:00  2013-06-28 23:03:00
#
#    tripduration             from_station_name  latitude_start  \
# 0           993     Lake Shore Dr & Monroe St        41.88105
# 1           623  Clinton St & Washington Blvd        41.88338
#
#    longitude_start  dpcapacity_start        to_station_name  latitude_end  \
# 0        -87.61697              11.0  Michigan Ave & Oak St      41.90096
# 1        -87.64117              31.0   Wells St & Walton St      41.89993
#
#    longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 0     -87.623777            15.0         73.9        10.0        12.7
# 1     -87.634430            19.0         69.1        10.0         6.9
#
#    precipitation        events
# 0        -9999.0  mostlycloudy
# 1        -9999.0  partlycloudy

# %%
bikes.tail(8)
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 50081  17534131  Subscriber    Male  2017-12-29 16:09:00  2017-12-29 16:19:00
# 50082  17534773  Subscriber    Male  2017-12-30 10:47:00  2017-12-30 10:53:00
# 50083  17534831  Subscriber    Male  2017-12-30 11:36:00  2017-12-30 11:55:00
# 50084  17534938  Subscriber    Male  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber    Male  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber    Male  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration           from_station_name  latitude_start  \
# 50081           617      Kingsbury St & Erie St       41.893882
# 50082           363        Larrabee St & Oak St       41.900219
# 50083          1175     Western Ave & Walton St       41.898418
# 50084          1625       State St & Pearson St       41.897448
# 50085           585    Halsted St & 35th St (*)       41.830661
# 50086           824    Kingsbury St & Kinzie St       41.889177
# 50087           178        Clinton St & Lake St       41.885637
# 50088           214  Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 50081       -87.641711              23.0            Canal St & Adams St
# 50082       -87.642985              19.0  Halsted St & Blackhawk St (*)
# 50083       -87.686596              19.0       Damen Ave & Clybourn Ave
# 50084       -87.628722              27.0              Clark St & Elm St
# 50085       -87.647172              16.0            Union Ave & Root St
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 50081     41.879255     -87.639904            47.0         14.0         1.5
# 50082     41.908537     -87.648627            20.0          3.9        10.0
# 50083     41.931931     -87.677856            15.0          3.9        10.0
# 50084     41.902973     -87.631280            27.0          5.0        10.0
# 50085     41.819102     -87.643278            11.0          5.0        10.0
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation        events
# 50081         6.9            0.0          snow
# 50082        13.8        -9999.0  mostlycloudy
# 50083        13.8        -9999.0  partlycloudy
# 50084        16.1        -9999.0  partlycloudy
# 50085        16.1        -9999.0  partlycloudy
# 50086        16.1        -9999.0  partlycloudy
# 50087        11.5        -9999.0  partlycloudy
# 50088        15.0        -9999.0  partlycloudy

# %% [markdown]
# ### Fully-qualified name
# Only the word after the last dot is the class name. The `bikes` variable has type `DataFrame`. Python always returns the location and module name of where the class was defined.
#
# ### Location and module name?
# The fully-qualified name holds the location in your computer where the class is defined. In this example, `pandas` is a directory that contains another directory `core` which contains a file `frame.py` which defines the `DataFrame` class.
#
# ### Package, sub-package, and module
# The top level directory of other files and directories containing Python files is technically called a **package**. In this example `pandas` is the package. All directories within the package are called **sub-packages** such as `core`. All Python files (those ending in .py) are called **modules**.
#
# ### Where are the packages located?
# Third-party packages are installed in the `site-packages` directory which itself is set up during Python installation. We can get the actual location with the help of the built-in `site` module's `getsitepackages`
# function.

# %%
import site
site.getsitepackages()
# Out:
# ['c:\\Users\\Office\\Desktop\\Intern_Project\\Internship-Program\\.venv',
#  'c:\\Users\\Office\\Desktop\\Intern_Project\\Internship-Program\\.venv\\Lib\\site-packages']

# %% [markdown]
# ## Select a single column from a DataFrame - a Series
# To select a single column from a DataFrame, pass the name of one of the columns to the brackets operator, `[]`. The returned object will be a pandas **Series**. Let's select the column name `tripduration`, assign it to a variable, and output it to the screen.

# %%
bikes.columns
# Out:
# Index(['trip_id', 'usertype', 'gender', 'starttime', 'stoptime',
#        'tripduration', 'from_station_name', 'latitude_start',
#        'longitude_start', 'dpcapacity_start', 'to_station_name',
#        'latitude_end', 'longitude_end', 'dpcapacity_end', 'temperature',
#        'visibility', 'wind_speed', 'precipitation', 'events'],
#       dtype='object')

# %%
tripduration = bikes["tripduration"]

# %% [markdown]
# ## `head` and `tail` methods work the same with a Series
# Use the **`head`** and **`tail`** methods to condense the output.

# %%
type(tripduration)
# Out:
# pandas.core.series.Series

# %% [markdown]
# ## Components of a Series - the index and the data
# A Series is simpler than a DataFrame with just a single dimension of data. It has two components - the **index** and the **data**. It is essentially a one-column DataFrame. Let's take a look at a stylized Series graphic.
#
# ![](images/series_components.png)
#
# The definition for the index and data components are the same as they are for a DataFrame.
#
# ### Output of Series vs DataFrame
# Notice that there is no nice HTML styling for the Series. It's just plain text. Also, below each Series will be some metadata on it - the **name**, **length**, and **dtype**.
#
# * The **name** is not important right now. If the Series is formed from a column of a DataFrame it will be set to that column name.
# * The **length** is the number of values in the Series
# * The **dtype** is the data type of the Series. Each column of data must be of only one particular data type. These will be covered later.
#
# It's important to note that this metadata is NOT part of the Series itself and is just some extra info pandas outputs for your information.

# %% [markdown]
# ## Exercises
# Use the **`bikes`** DataFrame for the following:

# %% [markdown]
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select the column **`events`**, the type of weather that was recorded and assign it to a variable with the same name. Output the first 10 values of it.</span>

# %%
df_bikess = pd.read_csv('data/bikes.csv')

# %%
events= df_bikess['events']

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">What type of object is **`events`**?</span>

# %%
events= df_bikess [['events']]

# %%
type(events)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Select the last 2 rows of the **`bikes`** DataFrame and assign it to the variable **`bikes_last_2`**. What type of object is **`bikes_last_2`**?</span>

# %%
bikes_last_2 = df_bikess.tail(2)
type(bikes_last_2)
bikes_last_2.sample()
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
#
#        tripduration     from_station_name  latitude_start  longitude_start  \
# 50087           178  Clinton St & Lake St       41.885637       -87.641823
#
#        dpcapacity_start           to_station_name  latitude_end  \
# 50087              23.0  Kingsbury St & Kinzie St     41.889177
#
#        longitude_end  dpcapacity_end  temperature  visibility  wind_speed  \
# 50087     -87.638506            31.0          7.0        10.0        11.5
#
#        precipitation        events
# 50087        -9999.0  partlycloudy

# %% [markdown]
# ## df.info() and df.describe() in pandas.
#
# **`df.info()` provides concise summary about a DataFrame, including:**
#
# + Memory usage
# + Number of rows and columns
# + Data types of each column
# + Number of non-null values in each column
# + It gives a quick overview of the structure and basic information about the DataFrame.
#
# **On the other hand, `df.describe()` provides statistical summary of the numeric columns in the DataFrame, including:**
#
# + Count: Number of non-null values
# + Mean: Average value
# + Standard deviation: Measure of how spread out the values are
# + Minimum and maximum values
# + Quartiles (25%, 50%, 75%)
# + It helps in understanding the central tendency, variability, and distribution of the numeric data in the DataFrame.
#
# <span  style="color:green; font-size:16px">In summary, `df.info()` is used for a quick overview of the DataFrame's structure and basic information, while `df.describe()` is used for a more detailed statistical analysis of the numeric columns in the DataFrame.</span>

# %%
bikes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50089 entries, 0 to 50088
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   trip_id            50089 non-null  int64
#  1   usertype           50089 non-null  object
#  2   gender             50089 non-null  object
#  3   starttime          50089 non-null  object
#  4   stoptime           50089 non-null  object
#  5   tripduration       50089 non-null  int64
#  6   from_station_name  50089 non-null  object
#  7   latitude_start     50083 non-null  float64
#  8   longitude_start    50083 non-null  float64
#  9   dpcapacity_start   50083 non-null  float64
#  10  to_station_name    50089 non-null  object
#  11  latitude_end       50077 non-null  float64
#  12  longitude_end      50077 non-null  float64
#  13  dpcapacity_end     50077 non-null  float64
#  14  temperature        50089 non-null  float64
#  15  visibility         50089 non-null  float64
#  16  wind_speed         50089 non-null  float64
#  17  precipitation      50089 non-null  float64
#  18  events             50089 non-null  object
# dtypes: float64(10), int64(2), object(7)
# memory usage: 7.3+ MB

# %%
bikes["tripduration"].head(20)
# Out:
# 0      993
# 1      623
# 2     1040
# 3      667
# 4      130
# 5      660
# 6      565
# 7      505
# 8     1300
# 9      922
# 10    1523
# 11    1697
# 12    2263
# 13    1365
# 14     610
# 15     415
# 16     487
# 17     622
# 18    5396
# 19     384
# Name: tripduration, dtype: int64

# %%
bikes.describe()
# Out:
#             trip_id  tripduration  latitude_start  longitude_start  \
# count  5.008900e+04  50089.000000    50083.000000     50083.000000
# mean   9.472308e+06    716.867755       41.900007       -87.644642
# std    4.914277e+06   1319.849896        0.034423         0.021512
# min    7.147000e+03     60.000000       41.744053       -87.802870
# 25%    5.332773e+06    356.000000       41.881032       -87.654752
# 50%    9.664991e+06    572.000000       41.891860       -87.641066
# 75%    1.363219e+07    906.000000       41.919936       -87.630585
# max    1.753625e+07  86188.000000       42.064313       -87.560115
#
#        dpcapacity_start  latitude_end  longitude_end  dpcapacity_end  \
# count      50083.000000  50077.000000   50077.000000    50077.000000
# mean          21.340215     41.900581     -87.644851       21.241708
# std            7.634167      0.034634       0.021499        7.556756
# min            0.000000     41.744053     -87.802870        0.000000
# 25%           15.000000     41.881320     -87.654787       15.000000
# 50%           19.000000     41.893832     -87.641088       19.000000
# 75%           23.000000     41.921540     -87.629928       23.000000
# max           55.000000     42.064313     -87.559275       55.000000
#
#         temperature    visibility    wind_speed  precipitation
# count  50089.000000  50089.000000  50089.000000   50089.000000
# mean      62.608237      8.148827      7.070111   -9239.626870
# std       48.151252    118.320794    178.937980    2648.862657
# min    -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 25%       52.000000     10.000000      6.900000   -9999.000000
# 50%       66.900000     10.000000     10.400000   -9999.000000
# 75%       75.900000     10.000000     12.700000   -9999.000000
# max       96.100000     10.000000     42.600000       0.390000

# %%
df_bikess.describe()
# Out:
#             trip_id  tripduration  latitude_start  longitude_start  \
# count  5.008900e+04  50089.000000    50083.000000     50083.000000
# mean   9.472308e+06    716.867755       41.900007       -87.644642
# std    4.914277e+06   1319.849896        0.034423         0.021512
# min    7.147000e+03     60.000000       41.744053       -87.802870
# 25%    5.332773e+06    356.000000       41.881032       -87.654752
# 50%    9.664991e+06    572.000000       41.891860       -87.641066
# 75%    1.363219e+07    906.000000       41.919936       -87.630585
# max    1.753625e+07  86188.000000       42.064313       -87.560115
#
#        dpcapacity_start  latitude_end  longitude_end  dpcapacity_end  \
# count      50083.000000  50077.000000   50077.000000    50077.000000
# mean          21.340215     41.900581     -87.644851       21.241708
# std            7.634167      0.034634       0.021499        7.556756
# min            0.000000     41.744053     -87.802870        0.000000
# 25%           15.000000     41.881320     -87.654787       15.000000
# 50%           19.000000     41.893832     -87.641088       19.000000
# 75%           23.000000     41.921540     -87.629928       23.000000
# max           55.000000     42.064313     -87.559275       55.000000
#
#         temperature    visibility    wind_speed  precipitation
# count  50089.000000  50089.000000  50089.000000   50089.000000
# mean      62.608237      8.148827      7.070111   -9239.626870
# std       48.151252    118.320794    178.937980    2648.862657
# min    -9999.000000  -9999.000000  -9999.000000   -9999.000000
# 25%       52.000000     10.000000      6.900000   -9999.000000
# 50%       66.900000     10.000000     10.400000   -9999.000000
# 75%       75.900000     10.000000     12.700000   -9999.000000
# max       96.100000     10.000000     42.600000       0.390000

# %% [markdown]
# # Selecting subsets of data:
#
# ### `The three indexers [ ], loc, iloc`

# %%
sampleDf = pd.read_csv('data/sample_data.csv', index_col=0)
# sampleDf = pd.read_csv('data/sample_data.csv')
sampleDf.head()
# Out:
#          state  color    food  age  height  score
# Jane        NY   blue   Steak   30     165    4.6
# Niko        TX  green    Lamb    2      70    8.3
# Aaron       FL    red   Mango   12     120    9.0
# Penelope    AL  white   Apple    4      80    3.3
# Dean        AK   gray  Cheese   32     180    1.8

# %% [markdown]
# **1- Select Multiple Columns with a List**
#
# You can select multiple columns by placing them in a list inside of just the brackets. Notice that a DataFrame and
# NOT a Series is returned.

# %%
#select the following columns:'color', 'age', 'score'
Select_Coulmn = sampleDf [['color','age','score']]
Select_Coulmn.columns
# Out:
# Index(['color', 'age', 'score'], dtype='object')

# %% [markdown]
# ## Exercises
# For the following exercises, make sure to use the `movie` dataset with title set as the index. It’s good practice to shorten your output with the head method.

# %% [markdown]
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select the column with the director’s name as a Series</span>

# %%
movie = pd.read_csv('data/movie.csv')
movie.columns
# Out:
# Index(['title', 'year', 'color', 'content_rating', 'duration', 'director_name',
#        'director_fb', 'actor1', 'actor1_fb', 'actor2', 'actor2_fb', 'actor3',
#        'actor3_fb', 'gross', 'genres', 'num_reviews', 'num_voted_users',
#        'plot_keywords', 'language', 'country', 'budget', 'imdb_score'],
#       dtype='object')

# %%
movie[['director_name']]
# Out:
#           director_name
# 0         James Cameron
# 1        Gore Verbinski
# 2            Sam Mendes
# 3     Christopher Nolan
# 4           Doug Walker
# ...                 ...
# 4911        Scott Smith
# 4912                NaN
# 4913   Benjamin Roberds
# 4914        Daniel Hsia
# 4915           Jon Gunn
#
# [4916 rows x 1 columns]

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select the column with the director’s name and number of Facebook likes.</span>

# %%
movie[['director_fb','director_name']]
# Out:
#       director_fb      director_name
# 0             0.0      James Cameron
# 1           563.0     Gore Verbinski
# 2             0.0         Sam Mendes
# 3         22000.0  Christopher Nolan
# 4           131.0        Doug Walker
# ...           ...                ...
# 4911          2.0        Scott Smith
# 4912          NaN                NaN
# 4913          0.0   Benjamin Roberds
# 4914          0.0        Daniel Hsia
# 4915         16.0           Jon Gunn
#
# [4916 rows x 2 columns]

# %% [markdown]
# **2-Selecting Subsets of Data from DataFrames with loc**
#
# - The `loc` indexer selects data in a different manner than just the brackets and has its own set of rules that we must learn.
# - Simultaneous row and column subset selection with loc
# - The loc indexer can select rows and columns simultaneously. This is not possible with just the brackets. This is done
# by separating the row and column selections with a comma. The selection will look something like this:
# **`df.loc[rows, cols]`**
# - loc primarily selects data by label
# Very importantly, loc primarily selects data by the `label` of the `rows` and `columns`.

# %%
df = pd.read_csv('data/sample_data.csv', index_col=0)

# %%
df.head(6)
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5

# %%
df.loc['Jane':'Christina','state':'food']
# Out:
#           state  color    food
# Jane         NY   blue   Steak
# Niko         TX  green    Lamb
# Aaron        FL    red   Mango
# Penelope     AL  white   Apple
# Dean         AK   gray  Cheese
# Christina    TX  black   Melon

# %% [markdown]
# **The possible types of row and column selections**
#
# `All of the following are valid objects available for both row and column selections with loc.`
# • A single label
#
# • A list of labels
#
# • A slice with labels
#
# • A boolean Series or array (covered in a later)

# %%
# Select two rows and three columns with loc
rows = ['Dean', 'Cornelia']
cols = ['age', 'state', 'score']
test_1 = df.loc[rows,cols]
test_1
# Out:
#           age state  score
# Dean       32    AK    1.8
# Cornelia   69    TX    2.2
# Cornelia   69    TX    NaN

# %%
cols = ['state', 'color']
df.loc['Jane':'Penelope', cols]
# Out:
#          state  color
# Jane        NY   blue
# Niko        TX  green
# Aaron       FL    red
# Penelope    AL  white

# %%
#Slice both the rows and columns
df.loc['Jane':'Christina',:]
# Out:
#           state  color    food  age  height  score
# Jane         NY   blue   Steak   30     165    4.6
# Niko         TX  green    Lamb    2      70    8.3
# Aaron        FL    red   Mango   12     120    9.0
# Penelope     AL  white   Apple    4      80    3.3
# Dean         AK   gray  Cheese   32     180    1.8
# Christina    TX  black   Melon   33     172    9.5

# %% [markdown]
# ## Exercises
# ### Exercise 1
# <span  style="color:green; font-size:16px">Read in the `movie` dataset and set the `title` column as the index. Select all columns for the movie ‘The Dark Knight Rises’.</span>

# %%
import pandas as pd

# %%
moves = pd.read_csv('data/movie.csv', index_col='title')

# %%
moves.head()
# Out:
#                                               year  color content_rating  \
# title
# Avatar                                      2009.0  Color          PG-13
# Pirates of the Caribbean: At World's End    2007.0  Color          PG-13
# Spectre                                     2015.0  Color          PG-13
# The Dark Knight Rises                       2012.0  Color          PG-13
# Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#                                             duration      director_name  \
# title
# Avatar                                         178.0      James Cameron
# Pirates of the Caribbean: At World's End       169.0     Gore Verbinski
# Spectre                                        148.0         Sam Mendes
# The Dark Knight Rises                          164.0  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens       NaN        Doug Walker
#
#                                             director_fb           actor1  \
# title
# Avatar                                              0.0      CCH Pounder
# Pirates of the Caribbean: At World's End          563.0      Johnny Depp
# Spectre                                             0.0  Christoph Waltz
# The Dark Knight Rises                           22000.0        Tom Hardy
# Star Wars: Episode VII - The Force Awakens        131.0      Doug Walker
#
#                                             actor1_fb            actor2  \
# title
# Avatar                                         1000.0  Joel David Moore
# Pirates of the Caribbean: At World's End      40000.0     Orlando Bloom
# Spectre                                       11000.0      Rory Kinnear
# The Dark Knight Rises                         27000.0    Christian Bale
# Star Wars: Episode VII - The Force Awakens      131.0        Rob Walker
#
#                                             actor2_fb  ... actor3_fb  \
# title                                                  ...
# Avatar                                          936.0  ...     855.0
# Pirates of the Caribbean: At World's End       5000.0  ...    1000.0
# Spectre                                         393.0  ...     161.0
# The Dark Knight Rises                         23000.0  ...   23000.0
# Star Wars: Episode VII - The Force Awakens       12.0  ...       NaN
#
#                                                   gross  \
# title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
#
#                                                                      genres  \
# title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
#
#                                            num_reviews  num_voted_users  \
# title
# Avatar                                           723.0           886204
# Pirates of the Caribbean: At World's End         302.0           471220
# Spectre                                          602.0           275868
# The Dark Knight Rises                            813.0          1144337
# Star Wars: Episode VII - The Force Awakens         NaN                8
#
#                                                                                 plot_keywords  \
# title
# Avatar                                                 avatar|future|marine|native|paraplegic
# Pirates of the Caribbean: At World's End    goddess|marriage ceremony|marriage proposal|pi...
# Spectre                                                   bomb|espionage|sequel|spy|terrorist
# The Dark Knight Rises                       deception|imprisonment|lawlessness|police offi...
# Star Wars: Episode VII - The Force Awakens                                                NaN
#
#                                            language country       budget  \
# title
# Avatar                                      English     USA  237000000.0
# Pirates of the Caribbean: At World's End    English     USA  300000000.0
# Spectre                                     English      UK  245000000.0
# The Dark Knight Rises                       English     USA  250000000.0
# Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#                                             imdb_score
# title
# Avatar                                             7.9
# Pirates of the Caribbean: At World's End           7.1
# Spectre                                            6.8
# The Dark Knight Rises                              8.5
# Star Wars: Episode VII - The Force Awakens         7.1
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Exercise 2
#
# <span  style="color:green; font-size:16px">Select all columns for the movies ‘Tangled’ and ‘Avatar’.</span>

# %%
moves.loc[['Tangled','Avatar']]
# Out:
#            year  color content_rating  duration  director_name  director_fb  \
# title
# Tangled  2010.0  Color             PG     100.0   Nathan Greno         15.0
# Avatar   2009.0  Color          PG-13     178.0  James Cameron          0.0
#
#                actor1  actor1_fb            actor2  actor2_fb  ... actor3_fb  \
# title                                                          ...
# Tangled  Brad Garrett      799.0      Donna Murphy      553.0  ...     284.0
# Avatar    CCH Pounder     1000.0  Joel David Moore      936.0  ...     855.0
#
#                gross                                             genres  \
# title
# Tangled  200807262.0  Adventure|Animation|Comedy|Family|Fantasy|Musi...
# Avatar   760505847.0                    Action|Adventure|Fantasy|Sci-Fi
#
#         num_reviews  num_voted_users  \
# title
# Tangled       324.0           294810
# Avatar        723.0           886204
#
#                                              plot_keywords language country  \
# title
# Tangled  17th century|based on fairy tale|disney|flower...  English     USA
# Avatar              avatar|future|marine|native|paraplegic  English     USA
#
#               budget  imdb_score
# title
# Tangled  260000000.0         7.8
# Avatar   237000000.0         7.9
#
# [2 rows x 21 columns]

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">What year was ‘Tangled’ and ‘Avatar’ made and what was their IMBD scores?</span>

# %%
moves.columns
# Out:
# Index(['year', 'color', 'content_rating', 'duration', 'director_name',
#        'director_fb', 'actor1', 'actor1_fb', 'actor2', 'actor2_fb', 'actor3',
#        'actor3_fb', 'gross', 'genres', 'num_reviews', 'num_voted_users',
#        'plot_keywords', 'language', 'country', 'budget', 'imdb_score'],
#       dtype='object')

# %%
moves.loc[['Tangled','Avatar'],['year', 'imdb_score']]
# Out:
#            year  imdb_score
# title
# Tangled  2010.0         7.8
# Avatar   2009.0         7.9

# %% [markdown]
# ### Exercise 4
# <span  style="color:green; font-size:16px">Can you tell what the data type of the year column is by just looking at its values?</span>

# %%
yearType = moves['year']
yearType.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 4916 entries, Avatar to My Date with Drew
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 4810 non-null   float64
# dtypes: float64(1)
# memory usage: 205.9+ KB

# %% [markdown]
# **3-Selecting Subsets of Data from DataFrames
# with iloc**
#
# The `iloc` indexer is very similar to loc but only uses `integer` location to make its selections.
# The word iloc itself stands for `integer location` so that should help remind you what it does.
# Simultaneous row and column subset selection with iloc
# Selection with iloc will look like the following with a comma separating the row and column selections.
# df.iloc[rows, cols]

# %% [markdown]
# All of the following are valid objects available for both row and column selections with iloc. The iloc indexer,
# unlike loc, is unable to do boolean selection.
#
# • A single integer
#
# • A list of integers
#
# • A slice with integers

# %% [markdown]
# **Select a single row or column as a DataFrame and NOT a Series**
#
# **Select some rows and a single column**
#
# You can select a single row (or column) and return a DataFrame and not a Series `if you use a list to make the selection.`
# Let’s replicate the selection from the previous example, but use a one-item list for the column selection.

# %%
movie.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 3                       The Dark Knight Rises  2012.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0     Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0         Sam Mendes          0.0  Christoph Waltz    11000.0
# 3     164.0  Christopher Nolan      22000.0        Tom Hardy    27000.0
# 4       NaN        Doug Walker        131.0      Doug Walker      131.0
#
#              actor2  ...  actor3_fb        gross  \
# 0  Joel David Moore  ...      855.0  760505847.0
# 1     Orlando Bloom  ...     1000.0  309404152.0
# 2      Rory Kinnear  ...      161.0  200074175.0
# 3    Christian Bale  ...    23000.0  448130642.0
# 4        Rob Walker  ...        NaN          NaN
#
#                             genres  num_reviews num_voted_users  \
# 0  Action|Adventure|Fantasy|Sci-Fi        723.0          886204
# 1         Action|Adventure|Fantasy        302.0          471220
# 2        Action|Adventure|Thriller        602.0          275868
# 3                  Action|Thriller        813.0         1144337
# 4                      Documentary          NaN               8
#
#                                        plot_keywords  language country  \
# 0             avatar|future|marine|native|paraplegic   English     USA
# 1  goddess|marriage ceremony|marriage proposal|pi...   English     USA
# 2                bomb|espionage|sequel|spy|terrorist   English      UK
# 3  deception|imprisonment|lawlessness|police offi...   English     USA
# 4                                                NaN       NaN     NaN
#
#         budget imdb_score
# 0  237000000.0        7.9
# 1  300000000.0        7.1
# 2  245000000.0        6.8
# 3  250000000.0        8.5
# 4          NaN        7.1
#
# [5 rows x 22 columns]

# %%
rows = [2, 3, 5]
cols = 4
movie.iloc[rows, cols]
# -----------------#
# VS
# Out:
# 2    148.0
# 3    164.0
# 5    132.0
# Name: duration, dtype: float64

# %%
rows = [2, 3, 5]
cols = [4]
movie.iloc[rows, cols]
# Out:
#    duration
# 2     148.0
# 3     164.0
# 5     132.0

# %%
movie.iloc[:3,:3]
# Out:
#                                       title    year  color
# 0                                    Avatar  2009.0  Color
# 1  Pirates of the Caribbean: At World's End  2007.0  Color
# 2                                   Spectre  2015.0  Color

# %%
movie.loc[:3,:"color"]
# Out:
#                                       title    year  color
# 0                                    Avatar  2009.0  Color
# 1  Pirates of the Caribbean: At World's End  2007.0  Color
# 2                                   Spectre  2015.0  Color
# 3                     The Dark Knight Rises  2012.0  Color

# %%
movie.head()
# Out:
#                                         title    year  color content_rating  \
# 0                                      Avatar  2009.0  Color          PG-13
# 1    Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 2                                     Spectre  2015.0  Color          PG-13
# 3                       The Dark Knight Rises  2012.0  Color          PG-13
# 4  Star Wars: Episode VII - The Force Awakens     NaN    NaN            NaN
#
#    duration      director_name  director_fb           actor1  actor1_fb  \
# 0     178.0      James Cameron          0.0      CCH Pounder     1000.0
# 1     169.0     Gore Verbinski        563.0      Johnny Depp    40000.0
# 2     148.0         Sam Mendes          0.0  Christoph Waltz    11000.0
# 3     164.0  Christopher Nolan      22000.0        Tom Hardy    27000.0
# 4       NaN        Doug Walker        131.0      Doug Walker      131.0
#
#              actor2  ...  actor3_fb        gross  \
# 0  Joel David Moore  ...      855.0  760505847.0
# 1     Orlando Bloom  ...     1000.0  309404152.0
# 2      Rory Kinnear  ...      161.0  200074175.0
# 3    Christian Bale  ...    23000.0  448130642.0
# 4        Rob Walker  ...        NaN          NaN
#
#                             genres  num_reviews num_voted_users  \
# 0  Action|Adventure|Fantasy|Sci-Fi        723.0          886204
# 1         Action|Adventure|Fantasy        302.0          471220
# 2        Action|Adventure|Thriller        602.0          275868
# 3                  Action|Thriller        813.0         1144337
# 4                      Documentary          NaN               8
#
#                                        plot_keywords  language country  \
# 0             avatar|future|marine|native|paraplegic   English     USA
# 1  goddess|marriage ceremony|marriage proposal|pi...   English     USA
# 2                bomb|espionage|sequel|spy|terrorist   English      UK
# 3  deception|imprisonment|lawlessness|police offi...   English     USA
# 4                                                NaN       NaN     NaN
#
#         budget imdb_score
# 0  237000000.0        7.9
# 1  300000000.0        7.1
# 2  245000000.0        6.8
# 3  250000000.0        8.5
# 4          NaN        7.1
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Exercises
# • Use the movie dataset for the following exercises
# ### Exercise 1
# <span  style="color:green; font-size:16px">Select the rows with integer location 10, 5, and 1</span>

# %%
movie.iloc[[1,5,10],:]
# Out:
#                                        title    year  color content_rating  \
# 1   Pirates of the Caribbean: At World's End  2007.0  Color          PG-13
# 5                                John Carter  2012.0  Color          PG-13
# 10        Batman v Superman: Dawn of Justice  2016.0  Color          PG-13
#
#     duration   director_name  director_fb        actor1  actor1_fb  \
# 1      169.0  Gore Verbinski        563.0   Johnny Depp    40000.0
# 5      132.0  Andrew Stanton        475.0  Daryl Sabara      640.0
# 10     183.0     Zack Snyder          0.0  Henry Cavill    15000.0
#
#              actor2  ...  actor3_fb        gross                    genres  \
# 1     Orlando Bloom  ...     1000.0  309404152.0  Action|Adventure|Fantasy
# 5   Samantha Morton  ...      530.0   73058679.0   Action|Adventure|Sci-Fi
# 10     Lauren Cohan  ...     2000.0  330249062.0   Action|Adventure|Sci-Fi
#
#     num_reviews num_voted_users  \
# 1         302.0          471220
# 5         462.0          212204
# 10        673.0          371639
#
#                                         plot_keywords  language country  \
# 1   goddess|marriage ceremony|marriage proposal|pi...   English     USA
# 5   alien|american civil war|male nipple|mars|prin...   English     USA
# 10  based on comic book|batman|sequel to a reboot|...   English     USA
#
#          budget imdb_score
# 1   300000000.0        7.1
# 5   263700000.0        6.6
# 10  250000000.0        6.9
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select the columns with integer location 10, 5, and 1</span>

# %%
movie.iloc[:,[1,5,10]]
# Out:
#         year      director_name  actor2_fb
# 0     2009.0      James Cameron      936.0
# 1     2007.0     Gore Verbinski     5000.0
# 2     2015.0         Sam Mendes      393.0
# 3     2012.0  Christopher Nolan    23000.0
# 4        NaN        Doug Walker       12.0
# ...      ...                ...        ...
# 4911  2013.0        Scott Smith      470.0
# 4912     NaN                NaN      593.0
# 4913  2013.0   Benjamin Roberds        0.0
# 4914  2012.0        Daniel Hsia      719.0
# 4915  2004.0           Jon Gunn       23.0
#
# [4916 rows x 3 columns]

# %% [markdown]
# ### Exercise 3
# <span  style="color:green; font-size:16px">Select rows with integer location 100 to 104 along with the column integer location 5.</span>

# %%
movie.iloc[100 : 105 , 5]
# Out:
# 100           Rob Cohen
# 101       David Fincher
# 102      Matthew Vaughn
# 103    Francis Lawrence
# 104      Jon Turteltaub
# Name: director_name, dtype: object

# %% [markdown]
# **4-Boolean Selection Single Conditions**
#
# Examples of Boolean Selection
#
# Let’s see some examples of actual questions (in plain English) that boolean selection can help us answer from the
# bikes dataset. The term query is used to refer to these sorts of questions.
#
# `• Find all rides by males`
#
# `• Find all rides with duration longer than 2 hours`
#
# `• Find all rides that took place between March and June of 2015.`
#
# `• Find all the rides with a duration longer than 2 hours by females with temperature higher than 90 degrees`
#
# **All queries have a logical condition**
#
# Each of the above queries have a strict logical condition that must be checked one row at a time.
# Keep or discard an entire row of data
# If you were to manually answer the above queries, you would need to scan each row and determine whether the row,
# as a whole, meets the condition. If so, then it is kept in the result, otherwise it is discarded.
# Each row will have a True or False value associated with it
# When you perform boolean selection, each row of the DataFrame (or value of a Series) will have a True or False
# value associated with it that corresponds to the outcome of the logical condition.

# %% [markdown]
# Creating boolean Series from column data
# By far the most common way to create a boolean Series will be from the values of one particular column. We will test
# a condition using one of the six comparison operators:
#
# `• <`
#
# `• <=`
#
# `• >`
#
# `• >=`
#
# `• ==`
#
# `• !=`

# %%
#Let’s begin by reading in the bikes dataset.
bikes = pd.read_csv("data/bikes.csv")

# %%
bikes.columns
# Out:
# Index(['trip_id', 'usertype', 'gender', 'starttime', 'stoptime',
#        'tripduration', 'from_station_name', 'latitude_start',
#        'longitude_start', 'dpcapacity_start', 'to_station_name',
#        'latitude_end', 'longitude_end', 'dpcapacity_end', 'temperature',
#        'visibility', 'wind_speed', 'precipitation', 'events'],
#       dtype='object')

# %%
bikes["gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
filt_1 = bikes["gender"]=='Male'
males_ony = bikes[filt_1]
males_ony["gender"].sample(10)
# Out:
# 3422     Male
# 32146    Male
# 2778     Male
# 11610    Male
# 37883    Male
# 22707    Male
# 39353    Male
# 12601    Male
# 42904    Male
# 12637    Male
# Name: gender, dtype: object

# %%
# ~ 
females_only = bikes[~filt_1]
females_only["gender"].sample(10)
# Out:
# 42248    Female
# 34576    Female
# 9040     Female
# 32774    Female
# 44755    Female
# 16733    Female
# 34190    Female
# 41157    Female
# 27649    Female
# 34552    Female
# Name: gender, dtype: object

# %%
filt_2 = bikes["gender"]=="Female"
filt_3 = bikes["tripduration"]<90

# %%
female_less_90 = bikes[filt_2 & filt_3]

# %%
female_less_90[["gender","tripduration"]]
# Out:
#        gender  tripduration
# 2485   Female            67
# 3366   Female            62
# 3629   Female            70
# 4930   Female            77
# 6430   Female            85
# 6862   Female            60
# 6914   Female            64
# 7909   Female            87
# 9551   Female            79
# 11168  Female            83
# 12500  Female            87
# 13621  Female            63
# 14283  Female            80
# 14839  Female            63
# 15385  Female            63
# 15543  Female            88
# 19586  Female            84
# 20421  Female            82
# 22834  Female            85
# 23247  Female            74
# 26596  Female            64
# 26671  Female            71
# 28258  Female            78
# 32520  Female            83
# 33200  Female            78
# 35215  Female            80
# 36699  Female            75
# 38148  Female            80
# 38634  Female            66
# 39827  Female            88
# 40800  Female            61
# 40847  Female            77
# 43435  Female            62
# 44965  Female            69
# 45922  Female            83
# 47165  Female            80
# 49783  Female            63

# %%
bikes["usertype"].unique()
# Out:
# array(['Subscriber', 'Customer', 'Dependent'], dtype=object)

# %%
f1= bikes["gender"] == "Female"

# %%
f2= bikes["usertype"] == "Customer"

# %%
logina = bikes[bikes["gender"] == "Female"]

# %%
logina = bikes[f1 | f2]

# %%
logina[["gender","usertype"]]
logina["gender"][logina["usertype"]=="Customer"]
# Out:
# 7031     Female
# 28102      Male
# 30389      Male
# 38033      Male
# 38794      Male
# 41190      Male
# 41740      Male
# 41963      Male
# 45551    Female
# Name: gender, dtype: object

# %% [markdown]
# Let’s create a boolean Series by determining which rows have a trip duration greater than 1000 seconds. To make the
# comparison, we select the tripduration column as a Series and compare it against the integer 1000.

# %%
bikes.sample(500)
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 23559   9158131  Subscriber  Female  2016-04-12 17:11:00  2016-04-12 17:20:00
# 33593  12517587  Subscriber  Female  2016-10-28 08:16:41  2016-10-28 08:25:19
# 9856    4305313  Subscriber  Female  2014-12-03 20:01:00  2014-12-03 20:09:00
# 36868  13436965  Subscriber  Female  2017-03-20 07:11:54  2017-03-20 07:17:57
# 9775    4274969  Subscriber  Female  2014-11-25 15:26:00  2014-11-25 15:31:00
# ...         ...         ...     ...                  ...                  ...
# 45402  16167118  Subscriber  Female  2017-09-01 08:54:57  2017-09-01 09:01:34
# 10588   4531042  Subscriber  Female  2015-02-13 06:50:00  2015-02-13 06:56:00
# 19152   7844148  Subscriber  Female  2015-10-08 16:59:00  2015-10-08 17:08:00
# 30244  11493374  Subscriber  Female  2016-08-24 07:41:27  2016-08-24 07:56:59
# 36623  13369629  Subscriber  Female  2017-03-07 12:31:43  2017-03-07 12:38:30
#
#        tripduration          from_station_name  latitude_start  \
# 23559           514      Green St & Madison St       41.881892
# 33593           518   Ogden Ave & Roosevelt Rd       41.866501
# 9856            522       Clark St & North Ave       41.911974
# 36868           363    Lincoln Ave & Winona St       41.974911
# 9775            306     Canal St & Harrison St       41.874337
# ...             ...                        ...             ...
# 45402           397     Leavitt St & North Ave       41.910153
# 10588           349        Wabash Ave & 8th St       41.871962
# 19152           566  Ogden Ave & Congress Pkwy       41.875010
# 30244           933        Morgan St & Polk St       41.871737
# 36623           407    Kedzie Ave & Leland Ave       41.966686
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 23559       -87.648789              19.0        Ogden Ave & Chicago Ave
# 33593       -87.684697              19.0      Ashland Ave & Harrison St
# 9856        -87.631942              15.0  Lakeview Ave & Fullerton Pkwy
# 36868       -87.692503              15.0       Western Ave & Leland Ave
# 9775        -87.639566              15.0       Peoria St & Jackson Blvd
# ...                ...               ...                            ...
# 45402       -87.682290              15.0   Marshfield Ave & Cortland St
# 10588       -87.626106              19.0        Dearborn St & Monroe St
# 19152       -87.673280              15.0       Peoria St & Jackson Blvd
# 30244       -87.651030              15.0           Rush St & Hubbard St
# 36623       -87.708052              15.0        Kedzie Ave & Foster Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 23559     41.896362     -87.654061            19.0         43.0        10.0
# 33593     41.874291     -87.667246            23.0         46.9         8.0
# 9856      41.925858     -87.638973            19.0         28.0        10.0
# 36868     41.966555     -87.688487            19.0         45.0         5.0
# 9775      41.877749     -87.649633            19.0         23.0        10.0
# ...             ...            ...             ...          ...         ...
# 45402     41.916017     -87.668879            23.0         61.0        10.0
# 10588     41.881320     -87.629521            27.0          6.1        10.0
# 19152     41.877749     -87.649633            19.0         73.9        10.0
# 30244     41.890011     -87.626293            15.0         71.1         8.0
# 36623     41.975672     -87.709261            15.0         51.1        10.0
#
#        wind_speed  precipitation  events
# 23559        12.7        -9999.0  cloudy
# 33593        11.5        -9999.0  cloudy
# 9856         10.4        -9999.0  cloudy
# 36868         8.1        -9999.0  cloudy
# 9775         11.5        -9999.0  cloudy
# ...           ...            ...     ...
# 45402        19.6        -9999.0  cloudy
# 10588         6.9        -9999.0  cloudy
# 19152        10.4        -9999.0  cloudy
# 30244        15.0            0.0  cloudy
# 36623        23.0        -9999.0  cloudy
#
# [500 rows x 19 columns]

# %%
#How many rows have a trip duration greater than 1000?
ex1 = bikes['tripduration'] > 1000
bikes[ex1]
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 2         10927  Subscriber  Female  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8         21028  Subscriber  Female  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10        24383  Subscriber  Female  2013-07-04 17:17:00  2013-07-04 17:42:00
# 11        24673  Subscriber  Female  2013-07-04 18:13:00  2013-07-04 18:42:00
# 12        26214  Subscriber  Female  2013-07-05 10:02:00  2013-07-05 10:40:00
# ...         ...         ...     ...                  ...                  ...
# 50058  17525403  Subscriber  Female  2017-12-23 13:48:00  2017-12-23 14:14:00
# 50077  17533484  Subscriber  Female  2017-12-29 09:13:00  2017-12-29 09:53:00
# 50080  17534057  Subscriber  Female  2017-12-29 15:28:00  2017-12-29 15:51:00
# 50083  17534831  Subscriber  Female  2017-12-30 11:36:00  2017-12-30 11:55:00
# 50084  17534938  Subscriber  Female  2017-12-30 13:07:00  2017-12-30 13:34:00
#
#        tripduration                from_station_name  latitude_start  \
# 2              1040     Sheffield Ave & Kingsbury St       41.909592
# 8              1300     Clinton St & Washington Blvd       41.883380
# 10             1523              Morgan St & 18th St       41.858086
# 11             1697       Ashland Ave & Armitage Ave       41.917859
# 12             2263         Jefferson St & Monroe St       41.880422
# ...             ...                              ...             ...
# 50058          1559        Michigan Ave & Madison St       41.882134
# 50077          2378             Clinton St & 18th St       41.857950
# 50080          1378  Cityfront Plaza Dr & Pioneer Ct       41.890573
# 50083          1175          Western Ave & Walton St       41.898418
# 50084          1625            State St & Pearson St       41.897448
#
#        longitude_start  dpcapacity_start                      to_station_name  \
# 2           -87.653497              15.0              Dearborn St & Monroe St
# 8           -87.641170              31.0                Wood St & Division St
# 10          -87.651073              15.0               Damen Ave & Pierce Ave
# 11          -87.668919              15.0           Lincoln Ave & Armitage Ave
# 12          -87.642746              19.0             Jefferson St & Monroe St
# ...                ...               ...                                  ...
# 50058       -87.625125              19.0                       Shedd Aquarium
# 50077       -87.640826              15.0                 Canal St & Taylor St
# 50080       -87.622072              23.0  Mies van der Rohe Way & Chestnut St
# 50083       -87.686596              19.0             Damen Ave & Clybourn Ave
# 50084       -87.628722              27.0                    Clark St & Elm St
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 2         41.881320     -87.629521            23.0         73.0        10.0
# 8         41.903320     -87.672730            15.0         71.1         8.0
# 10        41.909396     -87.677692            19.0         79.0        10.0
# 11        41.918273     -87.638116            19.0         79.0        10.0
# 12        41.880422     -87.642746            19.0         79.0        10.0
# ...             ...            ...             ...          ...         ...
# 50058     41.867226     -87.615355            55.0         28.0        10.0
# 50077     41.870257     -87.639474            15.0         12.9         9.0
# 50080     41.898587     -87.621915            19.0         14.0         1.5
# 50083     41.931931     -87.677856            15.0          3.9        10.0
# 50084     41.902973     -87.631280            27.0          5.0        10.0
#
#        wind_speed  precipitation  events
# 2            16.1       -9999.00  cloudy
# 8             0.0       -9999.00  cloudy
# 10            9.2       -9999.00  cloudy
# 11           10.4       -9999.00  cloudy
# 12            0.0       -9999.00  cloudy
# ...           ...            ...     ...
# 50058         8.1       -9999.00  cloudy
# 50077         4.6       -9999.00  cloudy
# 50080         6.9           0.01  cloudy
# 50083        13.8       -9999.00  cloudy
# 50084        16.1       -9999.00  cloudy
#
# [10178 rows x 19 columns]

# %%
#Let’s find all the rides longer than 1,000 seconds when it was cloudy.
fUN1 = bikes['tripduration'] > 1000
fUN2 = bikes['events'] == 'cloudy'
bikes[fUN1 & fUN2]
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 2         10927  Subscriber  Female  2013-06-30 14:43:00  2013-06-30 15:01:00
# 8         21028  Subscriber  Female  2013-07-03 15:21:00  2013-07-03 15:42:00
# 10        24383  Subscriber  Female  2013-07-04 17:17:00  2013-07-04 17:42:00
# 11        24673  Subscriber  Female  2013-07-04 18:13:00  2013-07-04 18:42:00
# 12        26214  Subscriber  Female  2013-07-05 10:02:00  2013-07-05 10:40:00
# ...         ...         ...     ...                  ...                  ...
# 50058  17525403  Subscriber  Female  2017-12-23 13:48:00  2017-12-23 14:14:00
# 50077  17533484  Subscriber  Female  2017-12-29 09:13:00  2017-12-29 09:53:00
# 50080  17534057  Subscriber  Female  2017-12-29 15:28:00  2017-12-29 15:51:00
# 50083  17534831  Subscriber  Female  2017-12-30 11:36:00  2017-12-30 11:55:00
# 50084  17534938  Subscriber  Female  2017-12-30 13:07:00  2017-12-30 13:34:00
#
#        tripduration                from_station_name  latitude_start  \
# 2              1040     Sheffield Ave & Kingsbury St       41.909592
# 8              1300     Clinton St & Washington Blvd       41.883380
# 10             1523              Morgan St & 18th St       41.858086
# 11             1697       Ashland Ave & Armitage Ave       41.917859
# 12             2263         Jefferson St & Monroe St       41.880422
# ...             ...                              ...             ...
# 50058          1559        Michigan Ave & Madison St       41.882134
# 50077          2378             Clinton St & 18th St       41.857950
# 50080          1378  Cityfront Plaza Dr & Pioneer Ct       41.890573
# 50083          1175          Western Ave & Walton St       41.898418
# 50084          1625            State St & Pearson St       41.897448
#
#        longitude_start  dpcapacity_start                      to_station_name  \
# 2           -87.653497              15.0              Dearborn St & Monroe St
# 8           -87.641170              31.0                Wood St & Division St
# 10          -87.651073              15.0               Damen Ave & Pierce Ave
# 11          -87.668919              15.0           Lincoln Ave & Armitage Ave
# 12          -87.642746              19.0             Jefferson St & Monroe St
# ...                ...               ...                                  ...
# 50058       -87.625125              19.0                       Shedd Aquarium
# 50077       -87.640826              15.0                 Canal St & Taylor St
# 50080       -87.622072              23.0  Mies van der Rohe Way & Chestnut St
# 50083       -87.686596              19.0             Damen Ave & Clybourn Ave
# 50084       -87.628722              27.0                    Clark St & Elm St
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 2         41.881320     -87.629521            23.0         73.0        10.0
# 8         41.903320     -87.672730            15.0         71.1         8.0
# 10        41.909396     -87.677692            19.0         79.0        10.0
# 11        41.918273     -87.638116            19.0         79.0        10.0
# 12        41.880422     -87.642746            19.0         79.0        10.0
# ...             ...            ...             ...          ...         ...
# 50058     41.867226     -87.615355            55.0         28.0        10.0
# 50077     41.870257     -87.639474            15.0         12.9         9.0
# 50080     41.898587     -87.621915            19.0         14.0         1.5
# 50083     41.931931     -87.677856            15.0          3.9        10.0
# 50084     41.902973     -87.631280            27.0          5.0        10.0
#
#        wind_speed  precipitation  events
# 2            16.1       -9999.00  cloudy
# 8             0.0       -9999.00  cloudy
# 10            9.2       -9999.00  cloudy
# 11           10.4       -9999.00  cloudy
# 12            0.0       -9999.00  cloudy
# ...           ...            ...     ...
# 50058         8.1       -9999.00  cloudy
# 50077         4.6       -9999.00  cloudy
# 50080         6.9           0.01  cloudy
# 50083        13.8       -9999.00  cloudy
# 50084        16.1       -9999.00  cloudy
#
# [10178 rows x 19 columns]

# %%
#Let’s find all the rides that were done by females or had trip durations longer than 1,000 seconds.
e1 = bikes['gender'] == 'Female'
e2= bikes['tripduration'] > 1000
bikes[e1 | e2]
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber  Female  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber  Female  2013-06-28 22:53:00  2013-06-28 23:03:00
# 2         10927  Subscriber  Female  2013-06-30 14:43:00  2013-06-30 15:01:00
# 3         12907  Subscriber  Female  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber  Female  2013-07-01 11:16:00  2013-07-01 11:18:00
# ...         ...         ...     ...                  ...                  ...
# 50084  17534938  Subscriber  Female  2017-12-30 13:07:00  2017-12-30 13:34:00
# 50085  17534969  Subscriber  Female  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber  Female  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber  Female  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration             from_station_name  latitude_start  \
# 0               993     Lake Shore Dr & Monroe St       41.881050
# 1               623  Clinton St & Washington Blvd       41.883380
# 2              1040  Sheffield Ave & Kingsbury St       41.909592
# 3               667       Carpenter St & Huron St       41.894556
# 4               130        Damen Ave & Pierce Ave       41.909396
# ...             ...                           ...             ...
# 50084          1625         State St & Pearson St       41.897448
# 50085           585      Halsted St & 35th St (*)       41.830661
# 50086           824      Kingsbury St & Kinzie St       41.889177
# 50087           178          Clinton St & Lake St       41.885637
# 50088           214    Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 0           -87.616970              11.0          Michigan Ave & Oak St
# 1           -87.641170              31.0           Wells St & Walton St
# 2           -87.653497              15.0        Dearborn St & Monroe St
# 3           -87.653449              19.0         Clark St & Randolph St
# 4           -87.677692              19.0         Damen Ave & Pierce Ave
# ...                ...               ...                            ...
# 50084       -87.628722              27.0              Clark St & Elm St
# 50085       -87.647172              16.0            Union Ave & Root St
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 0         41.900960     -87.623777            15.0         73.9        10.0
# 1         41.899930     -87.634430            19.0         69.1        10.0
# 2         41.881320     -87.629521            23.0         73.0        10.0
# 3         41.884576     -87.631890            31.0         72.0        10.0
# 4         41.909396     -87.677692            19.0         73.0        10.0
# ...             ...            ...             ...          ...         ...
# 50084     41.902973     -87.631280            27.0          5.0        10.0
# 50085     41.819102     -87.643278            11.0          5.0        10.0
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation  events
# 0            12.7        -9999.0  cloudy
# 1             6.9        -9999.0  cloudy
# 2            16.1        -9999.0  cloudy
# 3            16.1        -9999.0  cloudy
# 4            17.3        -9999.0  cloudy
# ...           ...            ...     ...
# 50084        16.1        -9999.0  cloudy
# 50085        16.1        -9999.0  cloudy
# 50086        16.1        -9999.0  cloudy
# 50087        11.5        -9999.0  cloudy
# 50088        15.0        -9999.0  cloudy
#
# [50089 rows x 19 columns]

# %% [markdown]
# **Inverting a condition with the not operator**
#
# The tilde character, ~, represents the not operator and inverts a condition.

# %%
#if we wanted all the rides with trip duration less than or equal to 1000,
f4 = bikes['tripduration']<=1000
bikes[f4]
# Out:
#         trip_id    usertype  gender            starttime             stoptime  \
# 0          7147  Subscriber  Female  2013-06-28 19:01:00  2013-06-28 19:17:00
# 1          7524  Subscriber  Female  2013-06-28 22:53:00  2013-06-28 23:03:00
# 3         12907  Subscriber  Female  2013-07-01 10:05:00  2013-07-01 10:16:00
# 4         13168  Subscriber  Female  2013-07-01 11:16:00  2013-07-01 11:18:00
# 5         13595  Subscriber  Female  2013-07-01 12:37:00  2013-07-01 12:48:00
# ...         ...         ...     ...                  ...                  ...
# 50082  17534773  Subscriber  Female  2017-12-30 10:47:00  2017-12-30 10:53:00
# 50085  17534969  Subscriber  Female  2017-12-30 13:34:00  2017-12-30 13:44:00
# 50086  17534972  Subscriber  Female  2017-12-30 13:34:00  2017-12-30 13:48:00
# 50087  17535645  Subscriber  Female  2017-12-31 09:30:00  2017-12-31 09:33:00
# 50088  17536246  Subscriber  Female  2017-12-31 15:22:00  2017-12-31 15:26:00
#
#        tripduration             from_station_name  latitude_start  \
# 0               993     Lake Shore Dr & Monroe St       41.881050
# 1               623  Clinton St & Washington Blvd       41.883380
# 3               667       Carpenter St & Huron St       41.894556
# 4               130        Damen Ave & Pierce Ave       41.909396
# 5               660      California Ave & 21st St       41.854016
# ...             ...                           ...             ...
# 50082           363          Larrabee St & Oak St       41.900219
# 50085           585      Halsted St & 35th St (*)       41.830661
# 50086           824      Kingsbury St & Kinzie St       41.889177
# 50087           178          Clinton St & Lake St       41.885637
# 50088           214    Clarendon Ave & Leland Ave       41.967968
#
#        longitude_start  dpcapacity_start                to_station_name  \
# 0           -87.616970              11.0          Michigan Ave & Oak St
# 1           -87.641170              31.0           Wells St & Walton St
# 3           -87.653449              19.0         Clark St & Randolph St
# 4           -87.677692              19.0         Damen Ave & Pierce Ave
# 5           -87.695445              15.0      Clark St & Wrightwood Ave
# ...                ...               ...                            ...
# 50082       -87.642985              19.0  Halsted St & Blackhawk St (*)
# 50085       -87.647172              16.0            Union Ave & Root St
# 50086       -87.638506              31.0  Halsted St & Blackhawk St (*)
# 50087       -87.641823              23.0       Kingsbury St & Kinzie St
# 50088       -87.650001              15.0     Clifton Ave & Lawrence Ave
#
#        latitude_end  longitude_end  dpcapacity_end  temperature  visibility  \
# 0         41.900960     -87.623777            15.0         73.9        10.0
# 1         41.899930     -87.634430            19.0         69.1        10.0
# 3         41.884576     -87.631890            31.0         72.0        10.0
# 4         41.909396     -87.677692            19.0         73.0        10.0
# 5         41.929546     -87.643118            15.0         73.0        10.0
# ...             ...            ...             ...          ...         ...
# 50082     41.908537     -87.648627            20.0          3.9        10.0
# 50085     41.819102     -87.643278            11.0          5.0        10.0
# 50086     41.908537     -87.648627            20.0          5.0        10.0
# 50087     41.889177     -87.638506            31.0          7.0        10.0
# 50088     41.968812     -87.657659            15.0         10.9        10.0
#
#        wind_speed  precipitation  events
# 0            12.7        -9999.0  cloudy
# 1             6.9        -9999.0  cloudy
# 3            16.1        -9999.0  cloudy
# 4            17.3        -9999.0  cloudy
# 5            17.3        -9999.0  cloudy
# ...           ...            ...     ...
# 50082        13.8        -9999.0  cloudy
# 50085        16.1        -9999.0  cloudy
# 50086        16.1        -9999.0  cloudy
# 50087        11.5        -9999.0  cloudy
# 50088        15.0        -9999.0  cloudy
#
# [39911 rows x 19 columns]

# %%
#Let’s reverse the condition for selecting rides by females or those with duration over 1,000 seconds. Logically, this should return only male riders with duration 1,000 or less.
e10 = bikes['gender'] == 'Female'
e20= bikes['tripduration'] > 1000
bikes[~(e10|e20)]
# Out:
# Empty DataFrame
# Columns: [trip_id, usertype, gender, starttime, stoptime, tripduration, from_station_name, latitude_start, longitude_start, dpcapacity_start, to_station_name, latitude_end, longitude_end, dpcapacity_end, temperature, visibility, wind_speed, precipitation, events]
# Index: []

# %% [markdown]
# ## Exercises
#
# ### Exercise 1
# <span  style="color:green; font-size:16px">Read in the movie dataset and set the index to be the title. Select all movies that have Tom Hanks as actor1. How
# many of these movies has he starred in?</span>

# %%
movie = pd.read_csv('data/movie.csv')
actor = movie['actor1'] == 'Tom Hanks'
movie[actor]
# Out:
#                                   title    year            color  \
# 43                          Toy Story 3  2010.0            Color
# 91                    The Polar Express  2004.0            Color
# 129                     Angels & Demons  2009.0            Color
# 205                   The Da Vinci Code  2006.0            Color
# 307                         Cloud Atlas  2012.0            Color
# 349                         Toy Story 2  1999.0            Color
# 390                           Cast Away  2000.0            Color
# 451                   Road to Perdition  2002.0            Color
# 530                        The Terminal  2004.0            Color
# 641                 Saving Private Ryan  1998.0            Color
# 648                           Apollo 13  1995.0            Color
# 651                     You've Got Mail  1998.0            Color
# 704                      The Green Mile  1999.0            Color
# 827                        Forrest Gump  1994.0  Black and White
# 836                    Captain Phillips  2013.0            Color
# 1185              A League of Their Own  1992.0  Black and White
# 1213                    Bridge of Spies  2015.0            Color
# 1258  Extremely Loud & Incredibly Close  2011.0            Color
# 1415                   Saving Mr. Banks  2013.0            Color
# 1572                          Toy Story  1995.0            Color
# 1645                       Larry Crowne  2011.0            Color
# 2364                                Big  1988.0            Color
# 3300                             Splash  1984.0            Color
# 4095                 That Thing You Do!  1996.0            Color
#
#      content_rating  duration     director_name  director_fb     actor1  \
# 43                G     103.0       Lee Unkrich        125.0  Tom Hanks
# 91                G     100.0   Robert Zemeckis          0.0  Tom Hanks
# 129           PG-13     146.0        Ron Howard       2000.0  Tom Hanks
# 205           PG-13     174.0        Ron Howard       2000.0  Tom Hanks
# 307               R     172.0        Tom Tykwer        670.0  Tom Hanks
# 349               G      82.0     John Lasseter        487.0  Tom Hanks
# 390           PG-13     143.0   Robert Zemeckis          0.0  Tom Hanks
# 451               R     117.0        Sam Mendes          0.0  Tom Hanks
# 530           PG-13     128.0  Steven Spielberg      14000.0  Tom Hanks
# 641               R     169.0  Steven Spielberg      14000.0  Tom Hanks
# 648              PG     140.0        Ron Howard       2000.0  Tom Hanks
# 651              PG     119.0       Nora Ephron          0.0  Tom Hanks
# 704               R     189.0    Frank Darabont          0.0  Tom Hanks
# 827           PG-13     142.0   Robert Zemeckis          0.0  Tom Hanks
# 836           PG-13     134.0   Paul Greengrass        521.0  Tom Hanks
# 1185             PG     128.0    Penny Marshall        545.0  Tom Hanks
# 1213          PG-13     142.0  Steven Spielberg      14000.0  Tom Hanks
# 1258          PG-13     129.0    Stephen Daldry        335.0  Tom Hanks
# 1415          PG-13     125.0  John Lee Hancock        102.0  Tom Hanks
# 1572              G      74.0     John Lasseter        487.0  Tom Hanks
# 1645          PG-13      98.0         Tom Hanks      15000.0  Tom Hanks
# 2364             PG     130.0    Penny Marshall        545.0  Tom Hanks
# 3300             PG     111.0        Ron Howard       2000.0  Tom Hanks
# 4095             PG     149.0         Tom Hanks      15000.0  Tom Hanks
#
#       actor1_fb                actor2  ...  actor3_fb        gross  \
# 43      15000.0     John Ratzenberger  ...      721.0  414984497.0
# 91      15000.0          Eddie Deezen  ...      267.0     665426.0
# 129     15000.0          Ayelet Zurer  ...      294.0  133375846.0
# 205     15000.0            Seth Gabel  ...      362.0  217536138.0
# 307     15000.0          Jim Sturgess  ...     1000.0   27098580.0
# 349     15000.0     John Ratzenberger  ...      967.0  245823397.0
# 390     15000.0          Paul Sanchez  ...      272.0  233630478.0
# 451     15000.0  Jennifer Jason Leigh  ...      818.0  104054514.0
# 530     15000.0           Chi McBride  ...      232.0   77032279.0
# 641     15000.0            Vin Diesel  ...    13000.0  216119491.0
# 648     15000.0           Miko Hughes  ...      552.0  172071312.0
# 651     15000.0        Jean Stapleton  ...      744.0  115731542.0
# 704     15000.0        Jeffrey DeMunn  ...      693.0  136801374.0
# 827     15000.0  Siobhan Fallon Hogan  ...      194.0  329691196.0
# 836     15000.0          Chris Mulkey  ...      186.0  107100855.0
# 1185    15000.0            Lori Petty  ...      251.0  107458785.0
# 1213    15000.0          Mark Rylance  ...      423.0   72306065.0
# 1258    15000.0           Thomas Horn  ...       64.0   31836745.0
# 1415    15000.0           Ruth Wilson  ...      825.0   83299761.0
# 1572    15000.0     John Ratzenberger  ...      802.0  191796233.0
# 1645    15000.0            Rob Riggle  ...      392.0   35565975.0
# 2364    15000.0            Jon Lovitz  ...      697.0  114968774.0
# 3300    15000.0         Howard Morris  ...       51.0   69800000.0
# 4095    15000.0       Charlize Theron  ...      982.0   25809813.0
#
#                                          genres  num_reviews num_voted_users  \
# 43    Adventure|Animation|Comedy|Family|Fantasy        453.0          544884
# 91           Adventure|Animation|Family|Fantasy        188.0          120798
# 129                            Mystery|Thriller        298.0          207839
# 205                            Mystery|Thriller        294.0          314253
# 307                                Drama|Sci-Fi        511.0          284825
# 349   Adventure|Animation|Comedy|Family|Fantasy        191.0          385871
# 390                     Adventure|Drama|Romance        221.0          394317
# 451                        Crime|Drama|Thriller        226.0          200359
# 530                                Comedy|Drama        151.0          303864
# 641                            Action|Drama|War        219.0          881236
# 648                     Adventure|Drama|History        159.0          208817
# 651                        Comedy|Drama|Romance        153.0          151812
# 704                 Crime|Drama|Fantasy|Mystery        186.0          782610
# 827                                Comedy|Drama        149.0         1251222
# 836                    Biography|Drama|Thriller        491.0          323353
# 1185                         Comedy|Drama|Sport         41.0           71754
# 1213                     Drama|History|Thriller        459.0          178118
# 1258                    Adventure|Drama|Mystery        283.0           81298
# 1415       Biography|Comedy|Drama|History|Music        405.0          117719
# 1572  Adventure|Animation|Comedy|Family|Fantasy        166.0          623757
# 1645                       Comedy|Drama|Romance        218.0           49205
# 2364        Comedy|Drama|Family|Fantasy|Romance         99.0          153468
# 3300                     Comedy|Fantasy|Romance         43.0           54723
# 4095                         Comedy|Drama|Music         75.0           50311
#
#                                           plot_keywords  language  country  \
# 43               college|day care|escape|teddy bear|toy   English      USA
# 91         boy|christmas|christmas eve|north pole|train   English      USA
# 129   conclave|illuminati|murder|reference to bernin...   English      USA
# 205   based on supposedly true story|holy grail|mary...   English      USA
# 307   composer|future|letter|nonlinear timeline|nurs...   English  Germany
# 349                     collector|dog|friend|rescue|toy   English      USA
# 390   christmas|island|love|survival|talking to inan...   English      USA
# 451                  1930s|blood|gun|on the run|revenge   English      USA
# 530   airport|construction site|fish out of water|fl...   English      USA
# 641     army|invasion|killed in action|normandy|soldier   English      USA
# 648   cape kennedy|news footage|reference to christo...   English      USA
# 651   bookstore|competing businesses|instant messagi...   English      USA
# 704   1930s|death row inmate|healing|prison guard|so...   English      USA
# 827           amputee|love|vietnam|vietnam war|war hero   English      USA
# 836               hijacking|hostage|leader|ship|somalia   English      USA
# 1185            baseball|friend|oregon|rivalry|softball   English      USA
# 1213                cia|cold war|lawyer|negotiation|spy   English      USA
# 1258                fear|mourning|mute|quest|revelation   English      USA
# 1415  author|disney|loss of father|reference to walt...   English      USA
# 1572             claw crane|cowboy|jealousy|rivalry|toy   English      USA
# 1645  bus stop|college|community college|scooter|spe...   English      USA
# 2364                  friend|job|new york city|toy|wish   English      USA
# 3300  cmnf|cmnf scene|mermaid|new york city|public n...   English      USA
# 4095                band|drummer|jazz|pennsylvania|song   English      USA
#
#            budget imdb_score
# 43    200000000.0        8.3
# 91    165000000.0        6.6
# 129   150000000.0        6.7
# 205   125000000.0        6.6
# 307   102000000.0        7.5
# 349    90000000.0        7.9
# 390    90000000.0        7.7
# 451    80000000.0        7.7
# 530    60000000.0        7.3
# 641    70000000.0        8.6
# 648    62000000.0        7.6
# 651    65000000.0        6.5
# 704    60000000.0        8.5
# 827    55000000.0        8.8
# 836    55000000.0        7.9
# 1185   40000000.0        7.2
# 1213   40000000.0        7.6
# 1258   40000000.0        6.9
# 1415   35000000.0        7.5
# 1572   30000000.0        8.3
# 1645   30000000.0        6.1
# 2364   18000000.0        7.3
# 3300    8000000.0        6.2
# 4095   26000000.0        6.9
#
# [24 rows x 22 columns]

# %%
movie.columns
# Out:
# Index(['title', 'year', 'color', 'content_rating', 'duration', 'director_name',
#        'director_fb', 'actor1', 'actor1_fb', 'actor2', 'actor2_fb', 'actor3',
#        'actor3_fb', 'gross', 'genres', 'num_reviews', 'num_voted_users',
#        'plot_keywords', 'language', 'country', 'budget', 'imdb_score'],
#       dtype='object')

# %% [markdown]
# ### Exercise 2
# <span  style="color:green; font-size:16px">Select movies with an IMDB score greater than 9.</span>

# %%
score = movie['imdb_score'] > 9
movie[score]
# Out:
#                          title    year  color content_rating  duration  \
# 1920  The Shawshank Redemption  1994.0  Color              R     142.0
# 2725          Towering Inferno     NaN  Color            NaN      65.0
# 2779                   Dekalog     NaN  Color          TV-MA      55.0
# 3402             The Godfather  1972.0  Color              R     175.0
# 4312      Kickboxer: Vengeance  2016.0    NaN            NaN      90.0
#
#              director_name  director_fb          actor1  actor1_fb  \
# 1920        Frank Darabont          0.0  Morgan Freeman    11000.0
# 2725        John Blanchard          0.0    Martin Short      770.0
# 2779                   NaN          NaN  Krystyna Janda       20.0
# 3402  Francis Ford Coppola          0.0       Al Pacino    14000.0
# 4312        John Stockwell        134.0    Matthew Ziff   260000.0
#
#                actor2  ...  actor3_fb        gross       genres  num_reviews  \
# 1920   Jeffrey DeMunn  ...      461.0   28341469.0  Crime|Drama        199.0
# 2725    Andrea Martin  ...      176.0          NaN       Comedy          NaN
# 2779  Olaf Lubaszenko  ...        2.0     447093.0        Drama         53.0
# 3402    Marlon Brando  ...     3000.0  134821952.0  Crime|Drama        208.0
# 4312       T.J. Storm  ...      354.0          NaN       Action          2.0
#
#      num_voted_users                                      plot_keywords  \
# 1920         1689764  escape from prison|first person narration|pris...
# 2725              10                                                NaN
# 2779           12590  meaning of life|moral challenge|morality|searc...
# 3402         1155770  crime family|mafia|organized crime|patriarch|r...
# 4312             246                                                NaN
#
#       language country      budget imdb_score
# 1920   English     USA  25000000.0        9.3
# 2725   English  Canada         NaN        9.5
# 2779    Polish  Poland         NaN        9.1
# 3402   English     USA   6000000.0        9.2
# 4312       NaN     USA  17000000.0        9.1
#
# [5 rows x 22 columns]

# %%
# rate = movie['content_rating'] == 'R'
movie[movie['content_rating'] == 'R']
# Out:
#                                    title    year            color  \
# 84                            The Lovers  2015.0            Color
# 94    Terminator 3: Rise of the Machines  2003.0            Color
# 113                            Alexander  2004.0            Color
# 124               The Matrix Revolutions  2003.0            Color
# 126                  The Matrix Reloaded  2003.0            Color
# ...                                  ...     ...              ...
# 4888                             Slacker  1991.0  Black and White
# 4892                              Exeter  2015.0            Color
# 4894                     The Puffy Chair  2005.0            Color
# 4899                               Clean  2004.0            Color
# 4908                         El Mariachi  1992.0            Color
#
#      content_rating  duration      director_name  director_fb  \
# 84                R     109.0       Roland Joffé        596.0
# 94                R     109.0    Jonathan Mostow         84.0
# 113               R     206.0       Oliver Stone          0.0
# 124               R     129.0     Lana Wachowski          0.0
# 126               R     138.0     Lana Wachowski          0.0
# ...             ...       ...                ...          ...
# 4888              R     100.0  Richard Linklater          0.0
# 4892              R      91.0      Marcus Nispel        158.0
# 4894              R      85.0        Jay Duplass        157.0
# 4899              R     110.0    Olivier Assayas        107.0
# 4908              R      81.0   Robert Rodriguez          0.0
#
#                actor1  actor1_fb               actor2  ...  actor3_fb  \
# 84     Tamsin Egerton      622.0        Alice Englert  ...      283.0
# 94         Nick Stahl      648.0          M.C. Gainey  ...      191.0
# 113   Anthony Hopkins    12000.0  Angelina Jolie Pitt  ...      591.0
# 124       Essie Davis      309.0          Collin Chou  ...      233.0
# 126     Steve Bastoni      234.0     Daniel Bernhardt  ...       30.0
# ...               ...        ...                  ...  ...        ...
# 4888   Tommy Pallotta        5.0    Richard Linklater  ...        0.0
# 4892  Ashley Tramonte      630.0      Brittany Curran  ...      265.0
# 4894     Mark Duplass      830.0        Katie Aselton  ...       10.0
# 4899    Maggie Cheung      576.0       Béatrice Dalle  ...       45.0
# 4908  Carlos Gallardo      121.0      Peter Marquardt  ...        6.0
#
#             gross                                             genres  \
# 84            NaN                    Action|Adventure|Romance|Sci-Fi
# 94    150350192.0                                      Action|Sci-Fi
# 113    34293771.0  Action|Adventure|Biography|Drama|History|Roman...
# 124   139259759.0                                      Action|Sci-Fi
# 126   281492479.0                                      Action|Sci-Fi
# ...           ...                                                ...
# 4888    1227508.0                                       Comedy|Drama
# 4892          NaN                            Horror|Mystery|Thriller
# 4894     192467.0                               Comedy|Drama|Romance
# 4899     136007.0                                Drama|Music|Romance
# 4908    2040920.0                Action|Crime|Drama|Romance|Thriller
#
#       num_reviews num_voted_users  \
# 84           10.0            2138
# 94          280.0          305340
# 113         248.0          138863
# 124         245.0          364948
# 126         275.0          421818
# ...           ...             ...
# 4888         61.0           15103
# 4892         43.0            3836
# 4894         51.0            4067
# 4899         81.0            3924
# 4908         56.0           52055
#
#                                           plot_keywords  language    country  \
# 84    1770s|british india|great barrier reef|india|ring   English    Belgium
# 94        drifter|exploding truck|future|machine|skynet   English        USA
# 113       ancient greece|conquest|greek|greek myth|king   English    Germany
# 124                    battle|epic|fight|future|machine   English  Australia
# 126   car motorcycle chase|one against many|oracle|p...   English        USA
# ...                                                 ...       ...        ...
# 4888  austin texas|moon|pap smear|texas|twenty somet...   English        USA
# 4892                 asylum|demon|party|secret|teenager   English        USA
# 4894      birthday|gift|motel|new york city|upholsterer   English        USA
# 4899                     jail|junkie|money|motel|singer    French     France
# 4908                 assassin|death|guitar|gun|mariachi   Spanish        USA
#
#            budget imdb_score
# 84            NaN        4.5
# 94    200000000.0        6.4
# 113   155000000.0        5.5
# 124   150000000.0        6.7
# 126   150000000.0        7.2
# ...           ...        ...
# 4888      23000.0        7.1
# 4892          NaN        4.6
# 4894      15000.0        6.6
# 4899       4500.0        6.9
# 4908       7000.0        6.9
#
# [2067 rows x 22 columns]

# %% [markdown]
# <span  style="color:green; font-size:16px">Write a function that accepts a single parameter to find the number of movies for a given content rating. Use the
# function to find the number of movies for ratings ‘R’, ‘PG-13’, and ‘PG’.</span>

# %%
def count_content_rating(target_rating) :
    return movie[movie['content_rating'] == target_rating].shape[0]


count_content_rating('R')
# Out:
# 2067
